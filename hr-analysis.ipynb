# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

sns.set(rc = {'figure.figsize':(15,5)})

# %%
df = pd.read_csv("/kaggle/input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.groupby(['Education','EducationField']).sum().reset_index()
# Out:
#     Education    EducationField   Age  DailyRate  DistanceFromHome  \
# 0           1   Human Resources    60       1453                24
# 1           1     Life Sciences  2277      58155               618
# 2           1         Marketing   463       7970                98
# 3           1           Medical  2039      54640               595
# 4           1             Other   129       3323                45
# 5           1  Technical Degree   500      14270               106
# 6           2   Human Resources    67       1904                 6
# 7           2     Life Sciences  4200      90692              1016
# 8           2         Marketing   915      18261               264
# 9           2           Medical  3663      85136               893
# 10          2             Other   643      16445               185
# 11          2  Technical Degree   907      19393               232
# 12          3   Human Resources   568      10183               141
# 13          3     Life Sciences  8541     181418              2015
# 14          3         Marketing  2243      44256               602
# 15          3           Medical  6634     144609              1756
# 16          3             Other   822      18395               222
# 17          3  Technical Degree  2058      48329               551
# 18          4   Human Resources   230       3731                54
# 19          4     Life Sciences  6825     142236              1597
# 20          4         Marketing  1996      37321               544
# 21          4           Medical  4123      85661               930
# 22          4             Other  1277      26373               271
# 23          4  Technical Degree  1183      27790               244
# 24          5   Human Resources    75        961                19
# 25          5     Life Sciences   644      14981               181
# 26          5         Marketing   413       7918                99
# 27          5           Medical   634      11733               166
# 28          5             Other    29        738                 9
# 29          5  Technical Degree   120       1379                30
#
#     EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# 0               2            3604                        6         152
# 1              67           65922                      182        4424
# 2              14           13937                       38         848
# 3              63           63235                      170        4038
# 4               5            6759                       17         343
# 5              19           12980                       54        1251
# 6               2            1757                        7         145
# 7             116          119803                      310        7821
# 8              24           22303                       70        1465
# 9              99           91645                      267        6476
# 10             19           21193                       53        1306
# 11             22           21187                       59        1462
# 12             16           18485                       40         911
# 13            233          242409                      649       15720
# 14             59           56420                      164        3842
# 15            183          191729                      498       11979
# 16             24           23128                       73        1370
# 17             57           61455                      164        3726
# 18              5            4540                       14         310
# 19            173          178643                      448       11486
# 20             52           55258                      133        3555
# 21            104          107623                      271        6706
# 22             33           34622                      102        2065
# 23             31           38832                       85        2174
# 24              2            3484                        5         126
# 25             17           14026                       41        1049
# 26             10           11055                       28         808
# 27             15           17733                       41        1091
# 28              1             455                        2          30
# 29              3            2330                       10         181
#
#     JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# 0                3  ...                         7            160
# 1              174  ...                       177           5360
# 2               38  ...                        35           1120
# 3              172  ...                       182           5040
# 4               13  ...                        12            400
# 5               48  ...                        50           1520
# 6                6  ...                         6            160
# 7              324  ...                       314           9280
# 8               61  ...                        69           1920
# 9              266  ...                       285           7920
# 10              49  ...                        51           1520
# 11              61  ...                        56           1760
# 12              44  ...                        49           1280
# 13             635  ...                       614          18640
# 14             161  ...                       162           4720
# 15             511  ...                       478          14640
# 16              64  ...                        61           1920
# 17             160  ...                       160           4560
# 18              14  ...                        14            400
# 19             473  ...                       473          13840
# 20             140  ...                       135           4160
# 21             284  ...                       302           8320
# 22              93  ...                        88           2640
# 23              83  ...                        81           2480
# 24               7  ...                         6            160
# 25              50  ...                        50           1360
# 26              28  ...                        27            800
# 27              42  ...                        34           1200
# 28               2  ...                         3             80
# 29               7  ...                         6            240
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                  1                 11                      4
# 1                 51                651                    185
# 2                 12                149                     34
# 3                 48                554                    194
# 4                  2                 31                     12
# 5                 11                 98                     58
# 6                  2                 11                      5
# 7                 86               1143                    303
# 8                 28                268                     69
# 9                 88               1135                    303
# 10                13                187                     57
# 11                16                277                     66
# 12                17                170                     40
# 13               173               2654                    646
# 14                44                729                    168
# 15               151               2079                    525
# 16                16                257                     63
# 17                42                552                    157
# 18                 5                105                     10
# 19               148               2142                    476
# 20                37                610                    129
# 21                89               1355                    290
# 22                22                370                     92
# 23                26                367                     85
# 24                 0                 16                      7
# 25                12                225                     50
# 26                14                129                     28
# 27                12                243                     49
# 28                 0                  4                      2
# 29                 1                 59                      8
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                 5              11                   1
# 1               177             495                 285
# 2                41             120                  70
# 3               177             377                 236
# 4                13              23                  19
# 5                59              77                  55
# 6                 5               7                   5
# 7               319             672                 450
# 8                67             148                  90
# 9               278             731                 370
# 10               52             121                  58
# 11               59             186                 131
# 12               44             111                  61
# 13              627            1600                 991
# 14              167             444                 281
# 15              495            1262                 785
# 16               69             173                 115
# 17              159             334                 223
# 18               14              43                  22
# 19              482            1348                 787
# 20              144             407                 229
# 21              290             784                 436
# 22               97             192                 132
# 23               84             235                 153
# 24                6              11                   7
# 25               48             123                  98
# 26               26              83                  44
# 27               42             143                  70
# 28                3               3                   2
# 29               10              38                  11
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 0                         0                     8
# 1                       123                   284
# 2                        40                    52
# 3                       137                   202
# 4                         7                    19
# 5                        18                    51
# 6                         0                     5
# 7                       177                   432
# 8                        43                    90
# 9                       252                   417
# 10                       23                    58
# 11                       68                   125
# 12                       28                    60
# 13                      561                   942
# 14                      141                   269
# 15                      371                   754
# 16                       35                   112
# 17                      126                   204
# 18                       16                    16
# 19                      413                   766
# 20                      115                   250
# 21                      245                   436
# 22                       69                   133
# 23                       78                   151
# 24                        0                     2
# 25                       46                    84
# 26                       18                    49
# 27                       60                    76
# 28                        2                     2
# 29                        4                    12
#
# [30 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
sns.countplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.boxplot(y=df['Age'],x=df['Department'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Age'>

# %%
sns.boxplot(x=df['Age'],y=df['Department'],hue=df['EducationField'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Department'>

# %%
sns.boxplot(x=df['Age'],y=df['Department'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Department'>

# %%
sns.countplot(x=df['Age'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=df['Department'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.countplot(x=df['Department'],hue=df['WorkLifeBalance'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.countplot(x=df['BusinessTravel'],hue=df['Attrition'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(x=df['Department'],hue=df['BusinessTravel'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.countplot(x=df['BusinessTravel'],hue=df['Department'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# NumCompaniesWorked        0.299635   0.038153         -0.029251   0.126317
# PercentSalaryHike         0.003634   0.022704          0.040235  -0.011111
# PerformanceRating         0.001904   0.000473          0.027110  -0.024539
# RelationshipSatisfaction  0.053535   0.007846          0.006557  -0.009118
# StandardHours                  NaN        NaN               NaN        NaN
# StockOptionLevel          0.037510   0.042143          0.044872   0.018422
# TotalWorkingYears         0.680381   0.014515          0.004628   0.148280
# TrainingTimesLastYear    -0.019621   0.002453         -0.036942  -0.025100
# WorkLifeBalance          -0.021490  -0.037848         -0.026556   0.009819
# YearsAtCompany            0.311309  -0.034055          0.009508   0.069114
# YearsInCurrentRole        0.212901   0.009932          0.018845   0.060236
# YearsSinceLastPromotion   0.216513  -0.033229          0.010029   0.054254
# YearsWithCurrManager      0.202089  -0.026363          0.014406   0.069065
#
#                           EmployeeCount  EmployeeNumber  \
# Age                                 NaN       -0.010145
# DailyRate                           NaN       -0.050990
# DistanceFromHome                    NaN        0.032916
# Education                           NaN        0.042070
# EmployeeCount                       NaN             NaN
# EmployeeNumber                      NaN        1.000000
# EnvironmentSatisfaction             NaN        0.017621
# HourlyRate                          NaN        0.035179
# JobInvolvement                      NaN       -0.006888
# JobLevel                            NaN       -0.018519
# JobSatisfaction                     NaN       -0.046247
# MonthlyIncome                       NaN       -0.014829
# MonthlyRate                         NaN        0.012648
# NumCompaniesWorked                  NaN       -0.001251
# PercentSalaryHike                   NaN       -0.012944
# PerformanceRating                   NaN       -0.020359
# RelationshipSatisfaction            NaN       -0.069861
# StandardHours                       NaN             NaN
# StockOptionLevel                    NaN        0.062227
# TotalWorkingYears                   NaN       -0.014365
# TrainingTimesLastYear               NaN        0.023603
# WorkLifeBalance                     NaN        0.010309
# YearsAtCompany                      NaN       -0.011240
# YearsInCurrentRole                  NaN       -0.008416
# YearsSinceLastPromotion             NaN       -0.009019
# YearsWithCurrManager                NaN       -0.009197
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.010146    0.024287        0.029820
# DailyRate                                0.018355    0.023381        0.046135
# DistanceFromHome                        -0.016075    0.031131        0.008783
# Education                               -0.027128    0.016775        0.042438
# EmployeeCount                                 NaN         NaN             NaN
# EmployeeNumber                           0.017621    0.035179       -0.006888
# EnvironmentSatisfaction                  1.000000   -0.049857       -0.008278
# HourlyRate                              -0.049857    1.000000        0.042861
# JobInvolvement                          -0.008278    0.042861        1.000000
# JobLevel                                 0.001212   -0.027853       -0.012630
# JobSatisfaction                         -0.006784   -0.071335       -0.021476
# MonthlyIncome                           -0.006259   -0.015794       -0.015271
# MonthlyRate                              0.037600   -0.015297       -0.016322
# NumCompaniesWorked                       0.012594    0.022157        0.015012
# PercentSalaryHike                       -0.031701   -0.009062       -0.017205
# PerformanceRating                       -0.029548   -0.002172       -0.029071
# RelationshipSatisfaction                 0.007665    0.001330        0.034297
# StandardHours                                 NaN         NaN             NaN
# StockOptionLevel                         0.003432    0.050263        0.021523
# TotalWorkingYears                       -0.002693   -0.002334       -0.005533
# TrainingTimesLastYear                   -0.019359   -0.008548       -0.015338
# WorkLifeBalance                          0.027627   -0.004607       -0.014617
# YearsAtCompany                           0.001458   -0.019582       -0.021355
# YearsInCurrentRole                       0.018007   -0.024106        0.008717
# YearsSinceLastPromotion                  0.016194   -0.026716       -0.024184
# YearsWithCurrManager                    -0.004999   -0.020123        0.025976
#
#                           JobLevel  ...  RelationshipSatisfaction  \
# Age                       0.509604  ...                  0.053535
# DailyRate                 0.002966  ...                  0.007846
# DistanceFromHome          0.005303  ...                  0.006557
# Education                 0.101589  ...                 -0.009118
# EmployeeCount                  NaN  ...                       NaN
# EmployeeNumber           -0.018519  ...                 -0.069861
# EnvironmentSatisfaction   0.001212  ...                  0.007665
# HourlyRate               -0.027853  ...                  0.001330
# JobInvolvement           -0.012630  ...                  0.034297
# JobLevel                  1.000000  ...                  0.021642
# JobSatisfaction          -0.001944  ...                 -0.012454
# MonthlyIncome             0.950300  ...                  0.025873
# MonthlyRate               0.039563  ...                 -0.004085
# NumCompaniesWorked        0.142501  ...                  0.052733
# PercentSalaryHike        -0.034730  ...                 -0.040490
# PerformanceRating        -0.021222  ...                 -0.031351
# RelationshipSatisfaction  0.021642  ...                  1.000000
# StandardHours                  NaN  ...                       NaN
# StockOptionLevel          0.013984  ...                 -0.045952
# TotalWorkingYears         0.782208  ...                  0.024054
# TrainingTimesLastYear    -0.018191  ...                  0.002497
# WorkLifeBalance           0.037818  ...                  0.019604
# YearsAtCompany            0.534739  ...                  0.019367
# YearsInCurrentRole        0.389447  ...                 -0.015123
# YearsSinceLastPromotion   0.353885  ...                  0.033493
# YearsWithCurrManager      0.375281  ...                 -0.000867
#
#                           StandardHours  StockOptionLevel  TotalWorkingYears  \
# Age                                 NaN          0.037510           0.680381
# DailyRate                           NaN          0.042143           0.014515
# DistanceFromHome                    NaN          0.044872           0.004628
# Education                           NaN          0.018422           0.148280
# EmployeeCount                       NaN               NaN                NaN
# EmployeeNumber                      NaN          0.062227          -0.014365
# EnvironmentSatisfaction             NaN          0.003432          -0.002693
# HourlyRate                          NaN          0.050263          -0.002334
# JobInvolvement                      NaN          0.021523          -0.005533
# JobLevel                            NaN          0.013984           0.782208
# JobSatisfaction                     NaN          0.010690          -0.020185
# MonthlyIncome                       NaN          0.005408           0.772893
# MonthlyRate                         NaN         -0.034323           0.026442
# NumCompaniesWorked                  NaN          0.030075           0.237639
# PercentSalaryHike                   NaN          0.007528          -0.020608
# PerformanceRating                   NaN          0.003506           0.006744
# RelationshipSatisfaction            NaN         -0.045952           0.024054
# StandardHours                       NaN               NaN                NaN
# StockOptionLevel                    NaN          1.000000           0.010136
# TotalWorkingYears                   NaN          0.010136           1.000000
# TrainingTimesLastYear               NaN          0.011274          -0.035662
# WorkLifeBalance                     NaN          0.004129           0.001008
# YearsAtCompany                      NaN          0.015058           0.628133
# YearsInCurrentRole                  NaN          0.050818           0.460365
# YearsSinceLastPromotion             NaN          0.014352           0.404858
# YearsWithCurrManager                NaN          0.024698           0.459188
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.019621        -0.021490
# DailyRate                              0.002453        -0.037848
# DistanceFromHome                      -0.036942        -0.026556
# Education                             -0.025100         0.009819
# EmployeeCount                               NaN              NaN
# EmployeeNumber                         0.023603         0.010309
# EnvironmentSatisfaction               -0.019359         0.027627
# HourlyRate                            -0.008548        -0.004607
# JobInvolvement                        -0.015338        -0.014617
# JobLevel                              -0.018191         0.037818
# JobSatisfaction                       -0.005779        -0.019459
# MonthlyIncome                         -0.021736         0.030683
# MonthlyRate                            0.001467         0.007963
# NumCompaniesWorked                    -0.066054        -0.008366
# PercentSalaryHike                     -0.005221        -0.003280
# PerformanceRating                     -0.015579         0.002572
# RelationshipSatisfaction               0.002497         0.019604
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.011274         0.004129
# TotalWorkingYears                     -0.035662         0.001008
# TrainingTimesLastYear                  1.000000         0.028072
# WorkLifeBalance                        0.028072         1.000000
# YearsAtCompany                         0.003569         0.012089
# YearsInCurrentRole                    -0.005738         0.049856
# YearsSinceLastPromotion               -0.002067         0.008941
# YearsWithCurrManager                  -0.004096         0.002759
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.311309            0.212901
# DailyRate                      -0.034055            0.009932
# DistanceFromHome                0.009508            0.018845
# Education                       0.069114            0.060236
# EmployeeCount                        NaN                 NaN
# EmployeeNumber                 -0.011240           -0.008416
# EnvironmentSatisfaction         0.001458            0.018007
# HourlyRate                     -0.019582           -0.024106
# JobInvolvement                 -0.021355            0.008717
# JobLevel                        0.534739            0.389447
# JobSatisfaction                -0.003803           -0.002305
# MonthlyIncome                   0.514285            0.363818
# MonthlyRate                    -0.023655           -0.012815
# NumCompaniesWorked             -0.118421           -0.090754
# PercentSalaryHike              -0.035991           -0.001520
# PerformanceRating               0.003435            0.034986
# RelationshipSatisfaction        0.019367           -0.015123
# StandardHours                        NaN                 NaN
# StockOptionLevel                0.015058            0.050818
# TotalWorkingYears               0.628133            0.460365
# TrainingTimesLastYear           0.003569           -0.005738
# WorkLifeBalance                 0.012089            0.049856
# YearsAtCompany                  1.000000            0.758754
# YearsInCurrentRole              0.758754            1.000000
# YearsSinceLastPromotion         0.618409            0.548056
# YearsWithCurrManager            0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# DailyRate                               -0.033229             -0.026363
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EmployeeCount                                 NaN                   NaN
# EmployeeNumber                          -0.009019             -0.009197
# EnvironmentSatisfaction                  0.016194             -0.004999
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobSatisfaction                         -0.018214             -0.027656
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [26 rows x 26 columns]

# %%
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_e452b_row0_col0, #T_e452b_row1_col1, #T_e452b_row2_col2, #T_e452b_row3_col3, #T_e452b_row5_col5, #T_e452b_row6_col6, #T_e452b_row7_col7, #T_e452b_row8_col8, #T_e452b_row9_col9, #T_e452b_row10_col10, #T_e452b_row11_col11, #T_e452b_row12_col12, #T_e452b_row13_col13, #T_e452b_row14_col14, #T_e452b_row15_col15, #T_e452b_row16_col16, #T_e452b_row18_col18, #T_e452b_row19_col19, #T_e452b_row20_col20, #T_e452b_row21_col21, #T_e452b_row22_col22, #T_e452b_row23_col23, #T_e452b_row24_col24, #T_e452b_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col1, #T_e452b_row0_col10, #T_e452b_row1_col14, #T_e452b_row2_col12, #T_e452b_row3_col18, #T_e452b_row6_col10, #T_e452b_row7_col23, #T_e452b_row8_col5, #T_e452b_row11_col10, #T_e452b_row12_col2, #T_e452b_row12_col11, #T_e452b_row12_col16, #T_e452b_row12_col19, #T_e452b_row13_col6, #T_e452b_row15_col2, #T_e452b_row16_col8, #T_e452b_row19_col1, #T_e452b_row19_col12, #T_e452b_row20_col7, #T_e452b_row20_col10, #T_e452b_row21_col7, #T_e452b_row24_col20 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col2, #T_e452b_row0_col15, #T_e452b_row1_col0, #T_e452b_row1_col11, #T_e452b_row2_col6, #T_e452b_row3_col1, #T_e452b_row6_col9, #T_e452b_row6_col19, #T_e452b_row7_col19, #T_e452b_row7_col21, #T_e452b_row10_col2, #T_e452b_row10_col9, #T_e452b_row10_col15, #T_e452b_row12_col14, #T_e452b_row14_col21, #T_e452b_row16_col12, #T_e452b_row18_col11, #T_e452b_row18_col15, #T_e452b_row20_col14, #T_e452b_row20_col24, #T_e452b_row21_col15, #T_e452b_row22_col15 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col3, #T_e452b_row23_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col4, #T_e452b_row0_col17, #T_e452b_row1_col4, #T_e452b_row1_col17, #T_e452b_row2_col4, #T_e452b_row2_col17, #T_e452b_row3_col4, #T_e452b_row3_col17, #T_e452b_row4_col0, #T_e452b_row4_col1, #T_e452b_row4_col2, #T_e452b_row4_col3, #T_e452b_row4_col4, #T_e452b_row4_col5, #T_e452b_row4_col6, #T_e452b_row4_col7, #T_e452b_row4_col8, #T_e452b_row4_col9, #T_e452b_row4_col10, #T_e452b_row4_col11, #T_e452b_row4_col12, #T_e452b_row4_col13, #T_e452b_row4_col14, #T_e452b_row4_col15, #T_e452b_row4_col16, #T_e452b_row4_col17, #T_e452b_row4_col18, #T_e452b_row4_col19, #T_e452b_row4_col20, #T_e452b_row4_col21, #T_e452b_row4_col22, #T_e452b_row4_col23, #T_e452b_row4_col24, #T_e452b_row4_col25, #T_e452b_row5_col4, #T_e452b_row5_col17, #T_e452b_row6_col4, #T_e452b_row6_col17, #T_e452b_row7_col4, #T_e452b_row7_col17, #T_e452b_row8_col4, #T_e452b_row8_col17, #T_e452b_row9_col4, #T_e452b_row9_col17, #T_e452b_row10_col4, #T_e452b_row10_col17, #T_e452b_row11_col4, #T_e452b_row11_col17, #T_e452b_row12_col4, #T_e452b_row12_col17, #T_e452b_row13_col4, #T_e452b_row13_col17, #T_e452b_row14_col4, #T_e452b_row14_col17, #T_e452b_row15_col4, #T_e452b_row15_col17, #T_e452b_row16_col4, #T_e452b_row16_col17, #T_e452b_row17_col0, #T_e452b_row17_col1, #T_e452b_row17_col2, #T_e452b_row17_col3, #T_e452b_row17_col4, #T_e452b_row17_col5, #T_e452b_row17_col6, #T_e452b_row17_col7, #T_e452b_row17_col8, #T_e452b_row17_col9, #T_e452b_row17_col10, #T_e452b_row17_col11, #T_e452b_row17_col12, #T_e452b_row17_col13, #T_e452b_row17_col14, #T_e452b_row17_col15, #T_e452b_row17_col16, #T_e452b_row17_col17, #T_e452b_row17_col18, #T_e452b_row17_col19, #T_e452b_row17_col20, #T_e452b_row17_col21, #T_e452b_row17_col22, #T_e452b_row17_col23, #T_e452b_row17_col24, #T_e452b_row17_col25, #T_e452b_row18_col4, #T_e452b_row18_col17, #T_e452b_row19_col4, #T_e452b_row19_col17, #T_e452b_row20_col4, #T_e452b_row20_col17, #T_e452b_row21_col4, #T_e452b_row21_col17, #T_e452b_row22_col4, #T_e452b_row22_col17, #T_e452b_row23_col4, #T_e452b_row23_col17, #T_e452b_row24_col4, #T_e452b_row24_col17, #T_e452b_row25_col4, #T_e452b_row25_col17 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col5, #T_e452b_row0_col6, #T_e452b_row0_col8, #T_e452b_row2_col15, #T_e452b_row3_col2, #T_e452b_row3_col10, #T_e452b_row3_col16, #T_e452b_row9_col18, #T_e452b_row10_col13, #T_e452b_row10_col14, #T_e452b_row10_col20, #T_e452b_row11_col1, #T_e452b_row14_col7, #T_e452b_row14_col20, #T_e452b_row16_col1, #T_e452b_row16_col6, #T_e452b_row16_col10, #T_e452b_row16_col19, #T_e452b_row16_col21, #T_e452b_row18_col0, #T_e452b_row20_col18, #T_e452b_row21_col11, #T_e452b_row22_col5, #T_e452b_row22_col18, #T_e452b_row23_col1, #T_e452b_row23_col5, #T_e452b_row23_col20, #T_e452b_row24_col5, #T_e452b_row24_col18, #T_e452b_row25_col5, #T_e452b_row25_col20 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col7, #T_e452b_row1_col7, #T_e452b_row2_col18, #T_e452b_row3_col24, #T_e452b_row7_col22, #T_e452b_row8_col22, #T_e452b_row11_col16, #T_e452b_row13_col7, #T_e452b_row14_col25, #T_e452b_row18_col1, #T_e452b_row19_col16, #T_e452b_row20_col5, #T_e452b_row21_col20 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col9, #T_e452b_row22_col11 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e452b_row0_col11, #T_e452b_row11_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_e452b_row0_col12, #T_e452b_row1_col6, #T_e452b_row1_col20, #T_e452b_row2_col10, #T_e452b_row5_col6, #T_e452b_row6_col1, #T_e452b_row6_col21, #T_e452b_row7_col2, #T_e452b_row8_col18, #T_e452b_row9_col10, #T_e452b_row11_col21, #T_e452b_row12_col20, #T_e452b_row12_col25, #T_e452b_row13_col5, #T_e452b_row15_col7, #T_e452b_row16_col20, #T_e452b_row19_col7, #T_e452b_row20_col21, #T_e452b_row22_col10, #T_e452b_row22_col20, #T_e452b_row23_col6, #T_e452b_row23_col10, #T_e452b_row23_col15, #T_e452b_row24_col6, #T_e452b_row25_col16 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col13 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e452b_row0_col14, #T_e452b_row7_col3, #T_e452b_row8_col6, #T_e452b_row9_col2, #T_e452b_row9_col7, #T_e452b_row10_col6, #T_e452b_row11_col6, #T_e452b_row11_col20, #T_e452b_row13_col8, #T_e452b_row15_col19, #T_e452b_row16_col2, #T_e452b_row18_col21, #T_e452b_row19_col2, #T_e452b_row24_col7, #T_e452b_row25_col6, #T_e452b_row25_col10, #T_e452b_row25_col21 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col16, #T_e452b_row2_col22, #T_e452b_row6_col13, #T_e452b_row13_col16, #T_e452b_row15_col23, #T_e452b_row18_col7, #T_e452b_row21_col22 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col18, #T_e452b_row2_col13, #T_e452b_row6_col5, #T_e452b_row7_col25, #T_e452b_row10_col23, #T_e452b_row14_col23, #T_e452b_row18_col2, #T_e452b_row24_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col19 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_e452b_row0_col20, #T_e452b_row2_col1, #T_e452b_row2_col24, #T_e452b_row3_col21, #T_e452b_row5_col21, #T_e452b_row6_col20, #T_e452b_row7_col0, #T_e452b_row8_col2, #T_e452b_row8_col10, #T_e452b_row9_col20, #T_e452b_row12_col21, #T_e452b_row15_col5, #T_e452b_row18_col3, #T_e452b_row18_col14, #T_e452b_row18_col19, #T_e452b_row19_col6, #T_e452b_row20_col13, #T_e452b_row21_col12, #T_e452b_row21_col24, #T_e452b_row22_col2, #T_e452b_row23_col7, #T_e452b_row24_col2, #T_e452b_row24_col21 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col21, #T_e452b_row1_col5, #T_e452b_row2_col0, #T_e452b_row5_col9, #T_e452b_row9_col8, #T_e452b_row10_col0, #T_e452b_row10_col21, #T_e452b_row10_col24, #T_e452b_row11_col2, #T_e452b_row12_col1, #T_e452b_row13_col15, #T_e452b_row14_col6, #T_e452b_row15_col6, #T_e452b_row16_col3, #T_e452b_row19_col14, #T_e452b_row20_col9, #T_e452b_row22_col1, #T_e452b_row24_col1, #T_e452b_row24_col14 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e452b_row0_col22 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_e452b_row0_col23 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e452b_row0_col24 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e452b_row0_col25 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e452b_row1_col2, #T_e452b_row1_col15, #T_e452b_row3_col14, #T_e452b_row6_col0, #T_e452
